# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import math
import numpy as np
def evaluacion(x):
  y=x+2*x**2-x**3+5*x**4
  return y
h=0.1
b=1
a=-1
n=20
count=0
i=1
sumapar=0
sumaimpar=0
print('{:^10}{:^10}{:^10}'.format('i','xi','evaluacion'))
print('{:^10}{:^10}{:^10}'.format('--------------','--------------','--------------'))
print('{:^10}{:^10}{:^10}'.format('0',a,evaluacion(a)))
while i<n:
  xi=a+i*h
  count+=1
  if i%2==0:
    sumapar+=evaluacion(xi)
  else:
    sumaimpar+=evaluacion(xi)
  i+=1
  print('{:^10}{:^10.1f}{:^10.4f}'.format(count,xi,evaluacion(xi)))
resultado=h/3*(evaluacion(a)+evaluacion(b))+(((2*h)/3)*sumapar)+((4*h)/3)*sumaimpar
print('{:^10}{:^10}{:^10}'.format(n,b,evaluacion(b)))
print()
print("la solucion es: ",resultado)
# Out:
#     i         xi    evaluacion
# ------------------------------------------
#     0         -1        7
#     1        -0.9     4.7295
#     2        -0.8     3.0400
#     3        -0.7     1.8235
#     4        -0.6     0.9840
#     5        -0.5     0.4375
#     6        -0.4     0.1120
#     7        -0.3    -0.0525
#     8        -0.2    -0.1040
#     9        -0.1    -0.0785
#     10       0.0      0.0000
#     11       0.1      0.1195
#     12       0.2      0.2800
#     13       0.3      0.4935
#     14       0.4      0.7840
#     15       0.5      1.1875
#     16       0.6      1.7520
#     17       0.7      2.5375
#     18       0.8      3.6160
#     19       0.9      5.0715
#     20        1         7
#
# la solucion es:  3.3334666666666677
