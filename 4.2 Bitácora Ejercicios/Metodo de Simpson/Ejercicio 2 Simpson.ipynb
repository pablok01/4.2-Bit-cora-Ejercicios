# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import math
import numpy as np
def evaluacion(x):
  y=np.exp(x)
  return y
h=0.1
b=1
a=0
n=10
count=0
i=1
sumapar=0
sumaimpar=0
print('{:^10}{:^10}{:^10}'.format('i','xi','evaluacion'))
print('{:^10}{:^10}{:^10}'.format('--------------','--------------','--------------'))
print('{:^10}{:^10}{:^10}'.format('0',a,evaluacion(a)))
while i<n:
  xi=a+i*h
  count+=1
  if i%2==0:
    sumapar+=evaluacion(xi)
  else:
    sumaimpar+=evaluacion(xi)
  i+=1
  print('{:^10}{:^10.1f}{:^10.4f}'.format(count,xi,evaluacion(xi)))
resultado=h/3*(evaluacion(a)+evaluacion(b))+(((2*h)/3)*sumapar)+((4*h)/3)*sumaimpar
print('{:^10}{:^10}{:^10}'.format(n,b,evaluacion(b)))
print()
print("la solucion es: ",resultado)
# Out:
#     i         xi    evaluacion
# ------------------------------------------
#     0         0        1.0
#     1        0.1      1.1052
#     2        0.2      1.2214
#     3        0.3      1.3499
#     4        0.4      1.4918
#     5        0.5      1.6487
#     6        0.6      1.8221
#     7        0.7      2.0138
#     8        0.8      2.2255
#     9        0.9      2.4596
#     10        1     2.718281828459045
#
# la solucion es:  1.7182827819248234
